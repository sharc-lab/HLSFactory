        0.045776587,
        0.021663452,
        -0.02392086,
    ]
)
# print(fc_params_linear)

# %%
# Author: Rishov Sarkar

# Convert floating-point array to fixed-point
# Sample Usage:
# to_fixed_point(A_fixp, A_float, iwidth=3)
def to_fixed_point(dst, src, *, width=None, iwidth, signed=True):
    if width is None:
        width = dst.dtype.itemsize * 8

    fwidth = width - iwidth
    epsilon = 1.0 / (2.0**fwidth)
    min_ = -1.0 * (2.0 ** (iwidth - 1)) if signed else 0.0
    max_ = (2.0 ** (iwidth - (1 if signed else 0))) - epsilon

    src = np.copy(src)
    src = src.reshape(dst.shape)
    src[src < min_] = min_
    src[src > max_] = max_
    if signed:
        src[src < 0] += 2**iwidth
    dst[:] = np.around(src * (2.0**fwidth)).astype(dst.dtype)


# Convert fixed-point array back to floating point
# Sample Usage:
# B_float = from_fixed_point(B_fixp, iwidth=3)
def from_fixed_point(src, *, width=None, iwidth, signed=True):
    if width is None:
        width = src.dtype.itemsize * 8

    fwidth = width - iwidth
    src = np.array(src, dtype=np.int64)
    if signed:
        src[src >= (2 ** (width - 1))] -= 2**width
    return src / (2.0**fwidth)

# %%
# Convert into 2-dimensional fc_params
for loop1 in range(144):
    for loop2 in range(10):
        fc_params[loop1][loop2] = fc_params_linear[loop1 * 10 + loop2]

# Flattening 2d Arrays to 1d
fc_params_ser = fc_params.flatten()
# print(fc_params_ser)
fc_params_bytes = fc_params_ser.tobytes()

# %%
# Function to send data to a specific client
def send_data(client_socket, data):
    try:
        client_socket.send(data.encode())
    except socket.error as e:
        print(f"Error occurred while sending data: {e}")


# Function to handle each client connection
def handle_client(client_socket, address):
    print(f"Connected to {address}")

    # Send data to the client
    send_data(client_socket, "Hello, client!")

    # Close the connection
    client_socket.close()
    print(f"Disconnected from {address}")

# %%
# Sending data to all the FPGAs one by one
j = 1
for i in range(len(HOST)):
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((HOST[i], PORT[i]))
        s.listen()
        conn, addr = s.accept()

        print("Server is listening...")

        with conn:
            print(f"Connected by {addr}")

            data = fc_params_bytes
            conn.sendall(data)
            np.set_printoptions(threshold=3)
            print("FC Weights sent to FPGA-" + str(j) + " : \n", fc_params)

    j = j + 1

start_time = time.time()
# Out:
# Server is listening...
# Connected by ('192.168.0.101', 36424)
# FC Weights sent to FPGA-1 :
#  [[-0.07988767  0.03766675 -0.0646291  ...  0.05440499  0.03811976
#   -0.03229927]
#  [-0.02204993 -0.03805529 -0.0503552  ... -0.03449374 -0.0808194
#   -0.06223328]
#  [-0.03409373 -0.07343289  0.11752969 ... -0.04945539 -0.07542431
#   -0.0500957 ]
#  ...
#  [ 0.01771073  0.0462289   0.10453591 ...  0.04499443 -0.04364932
#    0.06742123]
#  [ 0.01219676 -0.00511775 -0.04473863 ... -0.09368214  0.00170857
#    0.02389243]
#  [ 0.02254919  0.07496932  0.03943498 ...  0.04577659  0.02166345
#   -0.02392086]]
# Server is listening...
# Connected by ('192.168.0.102', 45202)
# FC Weights sent to FPGA-2 :
#  [[-0.07988767  0.03766675 -0.0646291  ...  0.05440499  0.03811976
#   -0.03229927]
#  [-0.02204993 -0.03805529 -0.0503552  ... -0.03449374 -0.0808194
#   -0.06223328]
#  [-0.03409373 -0.07343289  0.11752969 ... -0.04945539 -0.07542431
#   -0.0500957 ]
#  ...
# ...

# %%
# Receiving the computed matrix from the FPGAs
ii = 0
PORT = [6000, 6001, 6002, 6003]

fpga_res = {}

for i in range(len(HOST)):
    arr = []
    arr1 = []

    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((HOST[i], PORT[i]))
        s.listen()
        conn, addr = s.accept()
        with conn:
            print(f"Connected by {addr}")

            for j in range(144 * 10):
                result_bytes = conn.recv(8)
                result = np.frombuffer(result_bytes)  # , dtype=np.int16)
                arr = result.copy()
                arr1.append(arr)

    arr1 = [x for y in arr1 for x in y]
    arr1 = np.array(list(arr1))  # , dtype='int16')
    arr1 = arr1.reshape(144, 10)

    ii = ii + 1

    fpga_res[ii] = arr1[::]
    np.set_printoptions(threshold=3)
    print("FC Weights received from FPGA- " + str(ii) + " : \n", fpga_res[ii])
# Out:
# Connected by ('192.168.0.101', 48876)
# FC Weights received from FPGA- 1 :
#  [[-0.07983398  0.03771973 -0.0645752  ...  0.05444336  0.03808594
#   -0.03234863]
#  [-0.02209473 -0.03808594 -0.05041504 ... -0.0345459  -0.08081055
#   -0.06225586]
#  [-0.03405762 -0.07348633  0.11755371 ... -0.04943848 -0.07543945
#   -0.05004883]
#  ...
#  [ 0.0177002   0.04626465  0.10449219 ...  0.04504395 -0.04370117
#    0.06738281]
#  [ 0.01220703 -0.00512695 -0.04467773 ... -0.09362793  0.00170898
#    0.02392578]
#  [ 0.02258301  0.07495117  0.03942871 ...  0.04577637  0.02160645
#   -0.02392578]]
# Connected by ('192.168.0.102', 52978)
# FC Weights received from FPGA- 2 :
#  [[-0.07983398  0.03771973 -0.0645752  ...  0.05444336  0.03808594
#   -0.03234863]
#  [-0.02209473 -0.03808594 -0.05041504 ... -0.0345459  -0.08081055
#   -0.06225586]
#  [-0.03405762 -0.07348633  0.11755371 ... -0.04943848 -0.07543945
#   -0.05004883]
#  ...
# ...

# %%
# Federated Averaging of fc_params

fc_params_update = (fpga_res[1] + fpga_res[2] + fpga_res[3] + fpga_res[4]) / 4
print(fc_params_update)
# Out:
# [[-0.07983398  0.03771973 -0.0645752  ...  0.05444336  0.03808594
#   -0.03234863]
#  [-0.02209473 -0.03808594 -0.05041504 ... -0.0345459  -0.08081055
#   -0.06225586]
#  [-0.03405762 -0.07348633  0.11755371 ... -0.04943848 -0.07543945
#   -0.05004883]
#  ...
#  [ 0.01757812  0.04541016  0.10360718 ...  0.04373169 -0.04382324
#    0.0690918 ]
#  [ 0.01220703 -0.00512695 -0.04467773 ... -0.09362793  0.00170898
#    0.02392578]
#  [ 0.02258301  0.07495117  0.03942871 ...  0.04577637  0.02160645
#   -0.02392578]]

# %%
# Flattening 2d Arrays to 1d
fc_params_ser = fc_params_update.flatten()
# print(fc_params_ser)
fc_params_bytes = fc_params_ser.tobytes()

# %%
PORT = [6004, 6005, 6006, 6007]

# %%
# Sending data to all the FPGAs one by one
j = 1
for i in range(len(HOST)):
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((HOST[i], PORT[i]))
        s.listen()
        conn, addr = s.accept()
        with conn:
            print(f"Connected by {addr}")

            data = fc_params_bytes
            conn.sendall(data)
            np.set_printoptions(threshold=3)
            print("FC Weights sent to FPGA-" + str(j) + " : \n", fc_params_update)
    j = j + 1
# Out:
# Connected by ('192.168.0.101', 37938)
# FC Weights sent to FPGA-1 :
#  [[-0.07983398  0.03771973 -0.0645752  ...  0.05444336  0.03808594
#   -0.03234863]
#  [-0.02209473 -0.03808594 -0.05041504 ... -0.0345459  -0.08081055
#   -0.06225586]
#  [-0.03405762 -0.07348633  0.11755371 ... -0.04943848 -0.07543945
#   -0.05004883]
#  ...
#  [ 0.01757812  0.04541016  0.10360718 ...  0.04373169 -0.04382324
#    0.0690918 ]
#  [ 0.01220703 -0.00512695 -0.04467773 ... -0.09362793  0.00170898
#    0.02392578]
#  [ 0.02258301  0.07495117  0.03942871 ...  0.04577637  0.02160645
#   -0.02392578]]
# Connected by ('192.168.0.102', 56956)
# FC Weights sent to FPGA-2 :
#  [[-0.07983398  0.03771973 -0.0645752  ...  0.05444336  0.03808594
#   -0.03234863]
#  [-0.02209473 -0.03808594 -0.05041504 ... -0.0345459  -0.08081055
#   -0.06225586]
#  [-0.03405762 -0.07348633  0.11755371 ... -0.04943848 -0.07543945
#   -0.05004883]
#  ...
#  [ 0.01757812  0.04541016  0.10360718 ...  0.04373169 -0.04382324
# ...

# %%
# Receiving the computed matrix from the FPGAs
ii = 0
PORT = [6008, 6009, 6010, 6011]

fpga_res1 = {}

for i in range(len(HOST)):
    arr = []
    arr1 = []

    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((HOST[i], PORT[i]))
        s.listen()
        conn, addr = s.accept()
        with conn:
            print(f"Connected by {addr}")

            for j in range(144 * 10):
                result_bytes = conn.recv(8)
                result = np.frombuffer(result_bytes)  # , dtype=np.int16)
                arr = result.copy()
                arr1.append(arr)

    arr1 = [x for y in arr1 for x in y]
    arr1 = np.array(list(arr1))  # , dtype='int16')
    arr1 = arr1.reshape(144, 10)

    ii = ii + 1

    fpga_res1[ii] = arr1[::]
    np.set_printoptions(threshold=3)
    print("FC Weights received from FPGA- " + str(ii) + " : \n", fpga_res1[ii])
# Out:
# Connected by ('192.168.0.101', 34390)
# FC Weights received from FPGA- 1 :
#  [[-0.07983398  0.03771973 -0.0645752  ...  0.05444336  0.03808594
#   -0.03234863]
#  [-0.02209473 -0.03808594 -0.05041504 ... -0.0345459  -0.08081055
#   -0.06225586]
#  [-0.03405762 -0.07348633  0.11755371 ... -0.04943848 -0.07543945
#   -0.05004883]
#  ...
#  [ 0.01757812  0.04541016  0.1036377  ...  0.04370117 -0.04382324
#    0.0690918 ]
#  [ 0.01220703 -0.00512695 -0.04467773 ... -0.09362793  0.00170898
#    0.02392578]
#  [ 0.02258301  0.07495117  0.03942871 ...  0.04577637  0.02160645
#   -0.02392578]]
# Connected by ('192.168.0.102', 44332)
# FC Weights received from FPGA- 2 :
#  [[-0.07983398  0.03771973 -0.0645752  ...  0.05444336  0.03808594
#   -0.03234863]
#  [-0.02209473 -0.03808594 -0.05041504 ... -0.0345459  -0.08081055
#   -0.06225586]
#  [-0.03405762 -0.07348633  0.11755371 ... -0.04943848 -0.07543945
#   -0.05004883]
#  ...
# ...
